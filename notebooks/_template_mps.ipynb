# %% [markdown]
# # nsa-eval — Apple Silicon (MPS) reproducible template
#
# Run on Mac M1/M2/M3 with PyTorch >= 2.3. Output JSON is written under `benchmarks/results/<date>/`.
#
# **Note**: as of v0.1 the MPS reference has not been validated end-to-end on a real Mac because the maintainer's machine is Linux. If you run this notebook and get numbers, please attach the JSON to issue #1.

# %%
# !uv pip install -e '.[dev,bench]'

# %%
import torch
print('mps available:', torch.backends.mps.is_available())
print('mps built:', torch.backends.mps.is_built())

# %%
# !nsa-eval run --config configs/config.yaml

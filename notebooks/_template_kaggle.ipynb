# %% [markdown]
# # nsa-eval — Kaggle T4 reproducible template
#
# Run this notebook end-to-end on Kaggle (Accelerator: GPU T4 x2 or P100). The output JSON under `/kaggle/working/benchmarks/results/<date>/` is the artifact this repo treats as canonical.
#
# If a cell fails, the failure is moved to `experiments/_wip/<short-name>/` per project convention — do not silently re-run.

# %%
# !pip install -q git+https://github.com/hinanohart/nsa-eval.git#egg=nsa-eval[dev,bench]

# %%
import torch
print('cuda:', torch.cuda.is_available(), torch.cuda.get_device_name(0) if torch.cuda.is_available() else None)

# %%
# Default config targets MPS; override device to cuda for Kaggle.
# !nsa-eval run --config <(echo 'model:\n  name: qwen25_0_5b\n  hf_id: Qwen/Qwen2.5-0.5B\n  dtype: bfloat16\nbenchmark:\n  name: niah\n  seqlens: [2048, 4096]\nattention:\n  name: full\n  params: {}\ndevice:\n  name: cuda\n  fallback: [cpu]\nseed: 0')
